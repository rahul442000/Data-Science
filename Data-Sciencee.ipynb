# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul442000/Data-Science/blob/main/Data-Sciencee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name= Rahul Soni
# Roll No.= 171321
# Batch No.= CS_74

# %%
import pandas as pd 
  
# reading csv file  
season_data=pd.read_csv("Season.csv")
ball_data=pd.read_csv("Ball_by_Ball.csv")
player_data=pd.read_csv("Player.csv")
team_data=pd.read_csv("Team.csv")
match_data=pd.read_csv("Match.csv")
pl_match_data=pd.read_csv("Player_Match.csv")

print("Season Data:\n",season_data.head(5))
print(season_data.dtypes)
print("\n\n")
print("Ball by ball:\n",ball_data.head(5))
print(ball_data.dtypes)
print("\n\n")
print("Player data:\n",player_data.head(5))
print(player_data.dtypes)
print("\n\n")
print("Team data:\n",team_data.head(5))
print(team_data.dtypes)
print("\n\n")
print("Match data:\n",match_data.head(5))
print(match_data.dtypes)
print("\n\n")
print("Player match data:\n",pl_match_data.head(5))
print(pl_match_data.describe(include='all'))
print(pl_match_data.dtypes)
# Out:
# Season Data:
#     Season_Id  Season_Year  Orange_Cap_Id  Purple_Cap_Id  Man_of_the_Series_Id
# 0          1         2008            100            102                    32
# 1          2         2009             18             61                    53
# 2          3         2010            133            131                   133
# 3          4         2011            162            194                   162
# 4          5         2012            162            190                   315
# Season_Id               int64
# Season_Year             int64
# Orange_Cap_Id           int64
# Purple_Cap_Id           int64
# Man_of_the_Series_Id    int64
# dtype: object
#
#
#
# Ball by ball:
#     Match_Id  Innings_Id  Over_Id  ...  Player_dissimal_Id  Dissimal_Type  Fielder_Id
# 0    335987           1        1  ...
# 1    335987           1        1  ...
# 2    335987           1        1  ...
# 3    335987           1        1  ...
# 4    335987           1        1  ...
#
# ...

# %%
import pandas as pd

# reading csv file  
match_data=pd.read_csv("Match.csv")

# Season Id
match_data['Season_Id'].value_counts().nlargest(10).plot.bar()

# %%
import pandas as pd

# reading csv file  
match_data=pd.read_csv("Match.csv")

match_data.describe(include='all').plot.bar()

# %%
import pandas as pd
# reading csv file  
match_data=pd.read_csv("Match.csv")
#Plot Match venue versus count
match_data['Venue_Name'].value_counts().nlargest(10).plot.bar()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# reading csv file  
season_data=pd.read_csv("Season.csv")
# Heat map
sns.heatmap(season_data, cmap='coolwarm',annot=True)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# reading csv file  
season_data=pd.read_csv("Season.csv")
# density plat
sns.distplot(season_data['Man_of_the_Series_Id'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from numpy import genfromtxt
import matplotlib.pyplot as plt

#line graph
per_data=genfromtxt('Season.csv',delimiter=',')
plt.plot(per_data)
plt.title('Season data')
plt.show()
